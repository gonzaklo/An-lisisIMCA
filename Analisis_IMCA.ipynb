# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Make data
u = np.linspace(-10, 10, 100)
v = np.linspace(-10, 10, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z)

# Set an equal aspect ratio
ax.set_aspect('equal')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pip install jupyterlab anywidget
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objects as go
import numpy as np

# Create data for the plot
x = np.linspace(-5, 5, 400)
y = np.linspace(-5, 5, 400)
X, Y = np.meshgrid(x, y)
Z = X**2*Y/(X**4 + Y**2)

# Create the 3D surface plot
fig = go.Figure(data=[go.Surface(z=Z, x=X, y=Y)])

fig.update_layout(
    width=500,
    height=500)

# Show the plot
fig.show()

# %%
import plotly.express as px
import numpy as np

x=np.linspace(-3,3, 100)
fig = px.line(x, y=1/(x**2-1), title="función real")
fig.show()
# Out:
# /tmp/ipykernel_92948/3648906061.py:5: RuntimeWarning:
#
# divide by zero encountered in divide

# %%
import plotly.graph_objects as go
import numpy as np

trace = go.Scatter(x=np.linspace(-8, 8, 501), y=1/(x**2+49/64-1))

fig = go.Figure(data=[trace])

fig.update_layout(
    yaxis_range=[-8,8]
)

fig.update_layout(
    width=500,
    height=500)

# Show the plot
fig.show()

# %%
    # %matplotlib widget
    import matplotlib.pyplot as plt
    import numpy as np

    x = np.linspace(-3, 3, 500) # 400 points between -10 and 10
    y = 1/(x**2 - 1)

    fig, ax = plt.subplots()
    ax.plot(x, y)
    plt.ylim(-5, 5)
    plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pip install watermark
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [watermark]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext watermark

# %watermark -v -m -p matplotlib,numpy,jupyterlab,anywidget,plotly,watermark

# %watermark -u -n -t -z
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.13.3
# IPython version      : 9.3.0
#
# matplotlib: 3.10.3
# numpy     : 2.2.6
# jupyterlab: 4.4.3
# anywidget : 0.9.18
# plotly    : 6.1.2
# watermark : 2.5.0
#
# Compiler    : GCC 14.2.0
# OS          : Linux
# Release     : 6.13.0-1002-asahi-arm
# Machine     : aarch64
# Processor   : aarch64
# CPU cores   : 8
# Architecture: 64bit
#
# Last updated: Sat Jun 07 2025 02:39:09-05
